# %% [markdown]
# # EDA Forest Fire

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from warnings import filterwarnings
filterwarnings('ignore')

# %%
df = pd.read_csv('forest_fire.csv',header=1)
df
# Out:
#     day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI   BUI  \
# 0    01    06  2012          29  57  18     0  65.7  3.4   7.6  1.3   3.4
# 1    02    06  2012          29  61  13   1.3  64.4  4.1   7.6    1   3.9
# 2    03    06  2012          26  82  22  13.1  47.1  2.5   7.1  0.3   2.7
# 3    04    06  2012          25  89  13   2.5  28.6  1.3   6.9    0   1.7
# 4    05    06  2012          27  77  16     0  64.8    3  14.2  1.2   3.9
# ..   ..   ...   ...         ...  ..  ..   ...   ...  ...   ...  ...   ...
# 241  26    09  2012          30  65  14     0  85.4   16  44.5  4.5  16.9
# 242  27    09  2012          28  87  15   4.4  41.1  6.5     8  0.1   6.2
# 243  28    09  2012          27  87  29   0.5  45.9  3.5   7.9  0.4   3.4
# 244  29    09  2012          24  54  18   0.1  79.7  4.3  15.2  1.7   5.1
# 245  30    09  2012          24  64  15   0.2  67.3  3.8  16.5  1.2   4.8
#
#      FWI     Classes
# 0    0.5   not fire
# 1    0.4   not fire
# ...

# %%
df.shape
# Out:
# (246, 14)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 246 entries, 0 to 245
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          246 non-null    object
#  1   month        245 non-null    object
#  2   year         245 non-null    object
#  3   Temperature  245 non-null    object
#  4    RH          245 non-null    object
#  5    Ws          245 non-null    object
#  6   Rain         245 non-null    object
#  7   FFMC         245 non-null    object
#  8   DMC          245 non-null    object
#  9   DC           245 non-null    object
#  10  ISI          245 non-null    object
#  11  BUI          245 non-null    object
#  12  FWI          245 non-null    object
#  13  Classes      244 non-null    object
# dtypes: object(14)
# memory usage: 27.0+ KB

# %% [markdown]
# - Its looks like there are somr features that needed to be changed their Dtype from object to numerical

# %%
# check columns with null value
df[df.isnull().any(axis=1)]
# Out:
#                                day month  year Temperature   RH   Ws Rain   \
# 122  Sidi-Bel Abbes Region Dataset   NaN   NaN         NaN  NaN  NaN   NaN
# 167                             14    07  2012          37   37   18   0.2
#
#      FFMC   DMC      DC   ISI   BUI      FWI Classes
# 122   NaN   NaN     NaN   NaN   NaN      NaN       NaN
# 167  88.9  12.9  14.6 9  12.5  10.4  fire          NaN

# %% [markdown]
# ## its looks like that dataset is divided into two region

# %%
df.loc[:122,'Region'] = 1
df.loc[122:,'Region'] = 2
df['Region'] = df['Region'].astype(int)

# %%
df
# Out:
#     day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI   BUI  \
# 0    01    06  2012          29  57  18     0  65.7  3.4   7.6  1.3   3.4
# 1    02    06  2012          29  61  13   1.3  64.4  4.1   7.6    1   3.9
# 2    03    06  2012          26  82  22  13.1  47.1  2.5   7.1  0.3   2.7
# 3    04    06  2012          25  89  13   2.5  28.6  1.3   6.9    0   1.7
# 4    05    06  2012          27  77  16     0  64.8    3  14.2  1.2   3.9
# ..   ..   ...   ...         ...  ..  ..   ...   ...  ...   ...  ...   ...
# 241  26    09  2012          30  65  14     0  85.4   16  44.5  4.5  16.9
# 242  27    09  2012          28  87  15   4.4  41.1  6.5     8  0.1   6.2
# 243  28    09  2012          27  87  29   0.5  45.9  3.5   7.9  0.4   3.4
# 244  29    09  2012          24  54  18   0.1  79.7  4.3  15.2  1.7   5.1
# 245  30    09  2012          24  64  15   0.2  67.3  3.8  16.5  1.2   4.8
#
#      FWI     Classes    Region
# 0    0.5   not fire          1
# ...

# %% [markdown]
# ## Removing the rows with null value

# %%
df[df.isnull().any(axis=1)]
# Out:
#                                day month  year Temperature   RH   Ws Rain   \
# 122  Sidi-Bel Abbes Region Dataset   NaN   NaN         NaN  NaN  NaN   NaN
# 167                             14    07  2012          37   37   18   0.2
#
#      FFMC   DMC      DC   ISI   BUI      FWI Classes    Region
# 122   NaN   NaN     NaN   NaN   NaN      NaN       NaN       2
# 167  88.9  12.9  14.6 9  12.5  10.4  fire          NaN       2

# %%
df.dropna(inplace=True)

# %%
df.iloc[122]
# Out:
# day                    day
# month                month
# year                  year
# Temperature    Temperature
#  RH                     RH
#  Ws                     Ws
# Rain                 Rain
# FFMC                  FFMC
# DMC                    DMC
# DC                      DC
# ISI                    ISI
# BUI                    BUI
# FWI                    FWI
# Classes          Classes
# Region                   2
# Name: 123, dtype: object

# %%
df.drop(123,inplace=True)

# %%
df.reset_index(drop=True,inplace=True)

# %%
df
# Out:
#     day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI   BUI  \
# 0    01    06  2012          29  57  18     0  65.7  3.4   7.6  1.3   3.4
# 1    02    06  2012          29  61  13   1.3  64.4  4.1   7.6    1   3.9
# 2    03    06  2012          26  82  22  13.1  47.1  2.5   7.1  0.3   2.7
# 3    04    06  2012          25  89  13   2.5  28.6  1.3   6.9    0   1.7
# 4    05    06  2012          27  77  16     0  64.8    3  14.2  1.2   3.9
# ..   ..   ...   ...         ...  ..  ..   ...   ...  ...   ...  ...   ...
# 238  26    09  2012          30  65  14     0  85.4   16  44.5  4.5  16.9
# 239  27    09  2012          28  87  15   4.4  41.1  6.5     8  0.1   6.2
# 240  28    09  2012          27  87  29   0.5  45.9  3.5   7.9  0.4   3.4
# 241  29    09  2012          24  54  18   0.1  79.7  4.3  15.2  1.7   5.1
# 242  30    09  2012          24  64  15   0.2  67.3  3.8  16.5  1.2   4.8
#
#      FWI     Classes    Region
# 0    0.5   not fire          1
# ...

# %% [markdown]
# ## some columns are misspacced so that is needed to be fixed

# %%
df.columns
# Out:
# Index(['day', 'month', 'year', 'Temperature', ' RH', ' Ws', 'Rain ', 'FFMC',
#        'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes  ', 'Region'],
#       dtype='object')

# %%
df.columns = df.columns.str.strip()

# %%
df.columns
# Out:
# Index(['day', 'month', 'year', 'Temperature', 'RH', 'Ws', 'Rain', 'FFMC',
#        'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes', 'Region'],
#       dtype='object')

# %% [markdown]
# ## changing the Dtypes to numerical

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 243 entries, 0 to 242
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          243 non-null    object
#  1   month        243 non-null    object
#  2   year         243 non-null    object
#  3   Temperature  243 non-null    object
#  4   RH           243 non-null    object
#  5   Ws           243 non-null    object
#  6   Rain         243 non-null    object
#  7   FFMC         243 non-null    object
#  8   DMC          243 non-null    object
#  9   DC           243 non-null    object
#  10  ISI          243 non-null    object
#  11  BUI          243 non-null    object
#  12  FWI          243 non-null    object
#  13  Classes      243 non-null    object
#  14  Region       243 non-null    int64
# dtypes: int64(1), object(14)
# memory usage: 28.6+ KB

# %%
df.head()
# Out:
#   day month  year Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  FWI  \
# 0  01    06  2012          29  57  18     0  65.7  3.4   7.6  1.3  3.4  0.5
# 1  02    06  2012          29  61  13   1.3  64.4  4.1   7.6    1  3.9  0.4
# 2  03    06  2012          26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1
# 3  04    06  2012          25  89  13   2.5  28.6  1.3   6.9    0  1.7    0
# 4  05    06  2012          27  77  16     0  64.8    3  14.2  1.2  3.9  0.5
#
#        Classes  Region
# 0  not fire          1
# 1  not fire          1
# 2  not fire          1
# 3  not fire          1
# 4  not fire          1

# %%
df.columns
# Out:
# Index(['day', 'month', 'year', 'Temperature', 'RH', 'Ws', 'Rain', 'FFMC',
#        'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes', 'Region'],
#       dtype='object')

# %% [markdown]
# - from dataset we can conclude that 'day','month','year','Temperatue','RH','Ws' needed to be change to integer
# - 'Rain','FFMC','DMC','DC','ISI','BUI','FWI' are needed to be changed into float datatype

# %%
objects = [features for features in df.columns if df[features].dtypes=='O']

# %%
for i in objects:
    if i != 'Classes':
        if i in ['Rain', 'FFMC', 'DMC', 'DC', 'ISI', 'BUI', 'FWI']:
            df[i] = df[i].astype(float)
        elif i in ['day', 'month', 'year', 'Temperature', 'RH', 'Ws']:
            df[i] = df[i].astype(int)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 243 entries, 0 to 242
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          243 non-null    int64
#  1   month        243 non-null    int64
#  2   year         243 non-null    int64
#  3   Temperature  243 non-null    int64
#  4   RH           243 non-null    int64
#  5   Ws           243 non-null    int64
#  6   Rain         243 non-null    float64
#  7   FFMC         243 non-null    float64
#  8   DMC          243 non-null    float64
#  9   DC           243 non-null    float64
#  10  ISI          243 non-null    float64
#  11  BUI          243 non-null    float64
#  12  FWI          243 non-null    float64
#  13  Classes      243 non-null    object
#  14  Region       243 non-null    int64
# dtypes: float64(7), int64(7), object(1)
# memory usage: 28.6+ KB

# %%
df.describe().T
# Out:
#              count         mean        std     min      25%     50%      75%  \
# day          243.0    15.761317   8.842552     1.0     8.00    16.0    23.00
# month        243.0     7.502058   1.114793     6.0     7.00     8.0     8.00
# year         243.0  2012.000000   0.000000  2012.0  2012.00  2012.0  2012.00
# Temperature  243.0    32.152263   3.628039    22.0    30.00    32.0    35.00
# RH           243.0    62.041152  14.828160    21.0    52.50    63.0    73.50
# Ws           243.0    15.493827   2.811385     6.0    14.00    15.0    17.00
# Rain         243.0     0.762963   2.003207     0.0     0.00     0.0     0.50
# FFMC         243.0    77.842387  14.349641    28.6    71.85    83.3    88.30
# DMC          243.0    14.680658  12.393040     0.7     5.80    11.3    20.80
# DC           243.0    49.430864  47.665606     6.9    12.35    33.1    69.10
# ISI          243.0     4.742387   4.154234     0.0     1.40     3.5     7.25
# ...

# %% [markdown]
# ## Clean the Target value

# %%
df['Classes'].value_counts()
# Out:
# fire             131
# not fire         101
# fire               4
# fire               2
# not fire           2
# not fire           1
# not fire           1
# not fire           1
# Name: Classes, dtype: int64

# %% [markdown]
# - As we can see there are lots of variation of same name

# %%
df['Classes'] = df['Classes'].str.strip()

# %%
df['Classes'].value_counts()
# Out:
# fire        137
# not fire    106
# Name: Classes, dtype: int64

# %% [markdown]
# ## Data Set of Region 1 :  Bejaia Region

# %%
df[:122]
# Out:
#      day  month  year  Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  \
# 0      1      6  2012           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4
# 1      2      6  2012           29  61  13   1.3  64.4  4.1   7.6  1.0  3.9
# 2      3      6  2012           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7
# 3      4      6  2012           25  89  13   2.5  28.6  1.3   6.9  0.0  1.7
# 4      5      6  2012           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9
# ..   ...    ...   ...          ...  ..  ..   ...   ...  ...   ...  ...  ...
# 117   26      9  2012           31  54  11   0.0  82.0  6.0  16.3  2.5  6.2
# 118   27      9  2012           31  66  11   0.0  85.7  8.3  24.9  4.0  9.0
# 119   28      9  2012           32  47  14   0.7  77.5  7.1   8.8  1.8  6.8
# 120   29      9  2012           26  80  16   1.8  47.4  2.9   7.7  0.3  3.0
# 121   30      9  2012           25  78  14   1.4  45.0  1.9   7.5  0.2  2.4
#
#      FWI   Classes  Region
# 0    0.5  not fire       1
# ...

# %% [markdown]
# ## Data Set of Region 2 : Sidi-Bel Abbes Region

# %%
df[122:]
# Out:
#      day  month  year  Temperature  RH  Ws  Rain  FFMC   DMC    DC  ISI   BUI  \
# 122    1      6  2012           32  71  12   0.7  57.1   2.5   8.2  0.6   2.8
# 123    2      6  2012           30  73  13   4.0  55.7   2.7   7.8  0.6   2.9
# 124    3      6  2012           29  80  14   2.0  48.7   2.2   7.6  0.3   2.6
# 125    4      6  2012           30  64  14   0.0  79.4   5.2  15.4  2.2   5.6
# 126    5      6  2012           32  60  14   0.2  77.1   6.0  17.6  1.8   6.5
# ..   ...    ...   ...          ...  ..  ..   ...   ...   ...   ...  ...   ...
# 238   26      9  2012           30  65  14   0.0  85.4  16.0  44.5  4.5  16.9
# 239   27      9  2012           28  87  15   4.4  41.1   6.5   8.0  0.1   6.2
# 240   28      9  2012           27  87  29   0.5  45.9   3.5   7.9  0.4   3.4
# 241   29      9  2012           24  54  18   0.1  79.7   4.3  15.2  1.7   5.1
# 242   30      9  2012           24  64  15   0.2  67.3   3.8  16.5  1.2   4.8
#
#      FWI   Classes  Region
# ...

# %%
df.to_csv('forest_fire_CLEANED.csv',index=False)

# %% [markdown]
# # EDA

# %% [markdown]
# - remove all the use less features like 'day','month','year'

# %%
df1 = df.drop(['day','month','year'], axis=1)

# %%
df1
# Out:
#      Temperature  RH  Ws  Rain  FFMC   DMC    DC  ISI   BUI  FWI   Classes  \
# 0             29  57  18   0.0  65.7   3.4   7.6  1.3   3.4  0.5  not fire
# 1             29  61  13   1.3  64.4   4.1   7.6  1.0   3.9  0.4  not fire
# 2             26  82  22  13.1  47.1   2.5   7.1  0.3   2.7  0.1  not fire
# 3             25  89  13   2.5  28.6   1.3   6.9  0.0   1.7  0.0  not fire
# 4             27  77  16   0.0  64.8   3.0  14.2  1.2   3.9  0.5  not fire
# ..           ...  ..  ..   ...   ...   ...   ...  ...   ...  ...       ...
# 238           30  65  14   0.0  85.4  16.0  44.5  4.5  16.9  6.5      fire
# 239           28  87  15   4.4  41.1   6.5   8.0  0.1   6.2  0.0  not fire
# 240           27  87  29   0.5  45.9   3.5   7.9  0.4   3.4  0.2  not fire
# 241           24  54  18   0.1  79.7   4.3  15.2  1.7   5.1  0.7  not fire
# 242           24  64  15   0.2  67.3   3.8  16.5  1.2   4.8  0.5  not fire
#
#      Region
# 0         1
# 1         1
# 2         1
# 3         1
# ...

# %% [markdown]
# - lets change fire to 1 and not fire to 0

# %%
df1['Classes'][df1['Classes'] == 'fire'] = 1
df1['Classes'][df1['Classes'] == 'not fire'] = 0

# %%
df1['Classes'].value_counts()
# Out:
# 1    137
# 0    106
# Name: Classes, dtype: int64

# %%
df1.head()
# Out:
#    Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  FWI Classes  Region
# 0           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4  0.5       0       1
# 1           29  61  13   1.3  64.4  4.1   7.6  1.0  3.9  0.4       0       1
# 2           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1       0       1
# 3           25  89  13   2.5  28.6  1.3   6.9  0.0  1.7  0.0       0       1
# 4           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9  0.5       0       1

# %%
# Change the datatype of Classes
df1['Classes'] = df1['Classes'].astype(int)

# %%
df1.hist(bins=50, figsize=(20,15), ec = 'b')
# Out:
# array([[<AxesSubplot: title={'center': 'Temperature'}>,
#         <AxesSubplot: title={'center': 'RH'}>,
#         <AxesSubplot: title={'center': 'Ws'}>],
#        [<AxesSubplot: title={'center': 'Rain'}>,
#         <AxesSubplot: title={'center': 'FFMC'}>,
#         <AxesSubplot: title={'center': 'DMC'}>],
#        [<AxesSubplot: title={'center': 'DC'}>,
#         <AxesSubplot: title={'center': 'ISI'}>,
#         <AxesSubplot: title={'center': 'BUI'}>],
#        [<AxesSubplot: title={'center': 'FWI'}>,
#         <AxesSubplot: title={'center': 'Classes'}>,
#         <AxesSubplot: title={'center': 'Region'}>]], dtype=object)

# %% [markdown]
# # Rest in Colab EDA 1.3

# %%
plt.figure(figsize=(20,6))
sns.heatmap(df1.corr(), annot=True)
plt.show()
